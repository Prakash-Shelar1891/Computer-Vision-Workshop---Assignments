# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = np.ones((400, 400, 3), dtype = 'uint8')*255
a = img.copy()

# %%
plt.imshow(a)

# %%
line = cv2.line(a, (50, 50), (350, 350), (0, 0, 0), 3)
plt.imshow(a)

# %%
b = img.copy()
rect = cv2.rectangle(b,(50, 50), (250, 250), (0, 0, 0), 2)

# %%
plt.imshow(b)

# %%
c = img.copy()
(x, y) = (int(img.shape[1]/2), int(img.shape[0]/2))
circle = cv2.circle(c, (x,y), (120), (0, 0, 0), 2)

# %%
plt.imshow(c)
